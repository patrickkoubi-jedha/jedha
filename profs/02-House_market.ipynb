# %% [markdown]
# # House Market

# %% [markdown]
# Let's go a little further into python.

# %% [markdown]
# 1. Download the four files “superficie.csv” / “nombre_de_sdb.csv” / “nombre_de_chambres.csv” / "house_price.csv"
#
# 2. Read the files and create the 4 corresponding Dataframes

# %%
import pandas as pd

# %%
house_price = pd.read_csv('house_price.csv', index_col=0)
nb_chambre = pd.read_csv("nombre_de_chambres.csv", names=["id", "nb_chambre"])
superficie = pd.read_csv("superficie.csv", header=None)
superficie.columns = ["id",'surface']
# nb_sdb = pd.read_csv("nombre_de_sdb.csv", header=None, index_col=0)
nb_sdb = pd.read_csv("nombre_de_sdb.csv", names=["id", "nb_sdb"])
nb_sdb
# Out:
#     id  nb_sdb
# 0    0       2
# 1    1       1
# 2    2       1
# 3    3       3
# 4    4       1
# ..  ..     ...
# 95  95       3
# 96  96       1
# 97  97       1
# 98  98       1
# 99  99       2
#
# [100 rows x 2 columns]

# %%
# house_price = house_price.drop("Unnamed: 0", axis=1)
# house_price.drop("Unnamed: 0", axis=1, inplace=True)

# %%
print(house_price)
print(nb_chambre)
print(nb_sdb)
print(superficie)
# Out:
#     id  house_price
# 0   14    1918154.0
# 1   30     739142.0
# 2   70    1621938.0
# 3   77    1319862.0
# 4   50     146250.0
# ..  ..          ...
# 95  15     157223.0
# 96  81    1616313.0
# 97  42     143573.0
# 98  19     974546.0
# 99   9     157433.0
#
# [100 rows x 2 columns]
#     id  nb_chambre
# 0    0           1
# 1    1           4
# 2    2           1
# 3    3           4
# 4    4           2
# ..  ..         ...
# 95  95           3
# 96  96           2
# 97  97           2
# 98  98           2
# 99  99           2
#
# [100 rows x 2 columns]
#     id  nb_sdb
# 0    0       2
# 1    1       1
# 2    2       1
# 3    3       3
# 4    4       1
# ..  ..     ...
# 95  95       3
# 96  96       1
# 97  97       1
# 98  98       1
# 99  99       2
#
# [100 rows x 2 columns]
#     id  surface
# 0    0    28844
# 1    1    27667
# 2    2    14742
# 3    3    28089
# 4    4    11713
# ..  ..      ...
# 95  95    11417
# 96  96    12126
# 97  97    16390
# 98  98    23738
# 99  99    14613
#
# [100 rows x 2 columns]

# %% [markdown]
# 3. Give a column name to the three datasets that don't have a header in the source file

# %%
# Out:
# Surface:
#    id  surface
# 0   0    28844
# 1   1    27667
# 2   2    14742
# 3   3    28089
# 4   4    11713
# Bathrooms
#    id  bathrooms
# 0   0          2
# 1   1          1
# 2   2          1
# 3   3          3
# 4   4          1
# Rooms
#    id  rooms
# 0   0      1
# 1   1      4
# 2   2      1
# 3   3      4
# 4   4      2
# House prices
#    id  house_price
# 0  14    1918154.0
# 1  30     739142.0
# 2  70    1621938.0
# 3  77    1319862.0
# 4  50     146250.0

# %%
# Out:
#    id  house_price
# 0  14    1918154.0
# 1  30     739142.0
# 2  70    1621938.0
# 3  77    1319862.0
# 4  50     146250.0

# %% [markdown]
# 4. Make an inner join of these four datasets into a single dataframe.

# %%
df = pd.merge(superficie, nb_chambre, on='id').merge(nb_sdb, on='id').merge(house_price, on='id')
df
# Out:
#     id  surface  nb_chambre  nb_sdb  house_price
# 0    0    28844           1       2    1421908.0
# 1    1    27667           4       1    1305091.0
# 2    2    14742           1       1     164373.0
# 3    3    28089           4       3    1441714.0
# 4    4    11713           2       1     108290.0
# ..  ..      ...         ...     ...          ...
# 95  95    11417           3       3     132599.0
# 96  96    12126           2       1     155828.0
# 97  97    16390           2       1     237061.0
# 98  98    23738           2       1     976422.0
# 99  99    14613           2       2     183621.0
#
# [100 rows x 5 columns]

# %% [markdown]
# 5. What is the average surface area of the houses in our dataset?

# %%
display(df['surface'].mean())
# Out:
# np.float64(20439.77)

# %% [markdown]
# 6. What is the median and average number of rooms?

# %%
print(f"avg_nb_room = {df['nb_chambre'].mean()}")
print(f"med_nb_room = {df['nb_chambre'].median()}")
# Out:
# avg_nb_room = 2.42
# med_nb_room = 2.0

# %% [markdown]
# 7. What is the average cost of a house?

# %%
df['house_price'].mean()
# Out:
# np.float64(767747.87)

# %% [markdown]
# 8. What is the average cost of a house, depending on the number of rooms it has?

# %%
df.groupby('nb_chambre')['house_price'].mean()
# Out:
# nb_chambre
# 1    980774.869565
# 2    642086.258065
# 3    645904.592593
# 4    888045.631579
# Name: house_price, dtype: float64

# %% [markdown]
# 10. The average cost per room doesn't tell us much. Let's try to categorize by size.
#
#   - Create a new column in your dataset that we'll call home_size
# Create five categories that respectively correspond to:
#       - "very large" $=$ "a house larger than 25,000 sqrt_feet"
#       - "large" $=$ "a house between 20,000 and 25,000 sqrt_feet"
#       - "medium" $=$ "a house between 15,000 and 20,000 sqrt_feet"
#       - "small" $=$ "a house between 10,000 and 15,000 sqrt_feet"
#       - "very small" $=$ a house less than 10,000 sqrt_feet"
#
# Fill in the corresponding rows in the house_size column.

# %%
def home_size(cat) -> str:
    if cat["surface"] > 25000:
        return 'very large'
    elif cat["surface"] > 20000:
        return 'large'
    elif cat["surface"] > 15000:
        return 'medium'
    elif cat["surface"] > 10000:
        return 'small'
    else:
        'very small'
    
df["home_size"] = df.apply(home_size, axis=1)
df

# df["home_size"] = df.apply(lambda x: if...)
# Out:
#     id  surface  nb_chambre  nb_sdb  house_price   home_size
# 0    0    28844           1       2    1421908.0  very large
# 1    1    27667           4       1    1305091.0  very large
# 2    2    14742           1       1     164373.0       small
# 3    3    28089           4       3    1441714.0  very large
# 4    4    11713           2       1     108290.0       small
# ..  ..      ...         ...     ...          ...         ...
# 95  95    11417           3       3     132599.0       small
# 96  96    12126           2       1     155828.0       small
# 97  97    16390           2       1     237061.0      medium
# 98  98    23738           2       1     976422.0       large
# 99  99    14613           2       2     183621.0       small
#
# [100 rows x 6 columns]

# %% [markdown]
# 11. What is the average cost of a house depending on its size category?

# %%
df.groupby("home_size")["house_price"].mean()
# Out:
# home_size
# large         7.325385e+05
# medium        3.256948e+05
# small         1.561387e+05
# very large    1.552456e+06
# Name: house_price, dtype: float64

# %% [markdown]
#  12. Apply the code below to view your result. What can you conclude?

# %%
import plotly.express as px
fig = px.scatter(df, x = "surface", y = "house_price", trendline = "ols")
fig.show()
# Out:
# c:\Users\dubos\miniforge3\envs\JedhaTraining\Lib\site-packages\kaleido\_sync_server.py:11: UserWarning:
#
#
#
# Warning: You have Plotly version 5.24.1, which is not compatible with this version of Kaleido (1.1.0).
#
# This means that static image generation (e.g. `fig.write_image()`) will not work.
#
# Please upgrade Plotly to version 6.1.1 or greater, or downgrade Kaleido to version 0.2.1.
