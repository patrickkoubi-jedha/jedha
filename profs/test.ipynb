# %%
import sys
from pathlib import Path

# Depuis profs/ → on remonte d'un niveau → on arrive dans projet/
root = Path.cwd().parent.resolve()

# Vérification (tu peux laisser ces prints pour debugger)
print("Répertoire courant       :", Path.cwd())
print("Répertoire ajouté au path :", root)
print("Existe ?", (root / "perso" / "utils" / "api" / "__init__.py").exists())

# Ajout au sys.path
sys.path.insert(0, str(root))

# Import avec le vrai nom du package
from perso.utils.api import MyGeckoApi

print("Import OK")
# Out:
# Répertoire courant       : c:\Projects\formation\jedha\dsfs-ft-40\profs
# Répertoire ajouté au path : C:\Projects\formation\jedha\dsfs-ft-40
# Existe ? True
# Import OK
